# %% [markdown]
# # Описание проекта

# %% [markdown]
# Заказчик этого исследования — большая телекоммуникационная компания, которая оказывает услуги на территории всего СНГ. Перед компанией стоит задача определить текущий уровень потребительской лояльности, или NPS (от англ. Net Promoter Score), среди клиентов из России.

# %% [markdown]
# ### Цель проекта
#
# Ответить на вопросы:
#
# - Как распределены участники опроса по возрасту, полу и возрасту? Каких пользователей больше: новых или старых? Пользователи из каких городов активнее участвовали в опросе?
# - Какие группы пользователей наиболее лояльны к сервису? Какие менее?
# - Какой общий NPS среди всех опрошенных?
# - Как можно описать клиентов, которые относятся к группе cторонников (англ. promoters)?

# %%
import pandas as pd

# %%
df = pd.read_csv('telecomm_csi.csv')
display(df.head(10))
# Out:
#    Unnamed: 0 user_id  lt_day is_new   age gender_segment  os_name  \
# 0           0  A001A2    2320    old  45.0         female  ANDROID
# 1           1  A001WF    2344    old  53.0           male  ANDROID
# 2           2  A003Q7     467    old  57.0           male  ANDROID
# 3           3  A004TB    4190    old  44.0         female      IOS
# 4           4  A004XT    1163    old  24.0           male  ANDROID
# 5           5  A005O0    5501    old  42.0         female  ANDROID
# 6           6  A0061R    1236    old  45.0           male  ANDROID
# 7           7  A009KS     313    new  35.0           male  ANDROID
# 8           8  A00AES    3238    old  36.0         female  ANDROID
# 9           9  A00F70    4479    old  54.0         female  ANDROID
#
#   cpe_type_name country            city age_segment traffic_segment  \
# 0    SMARTPHONE  Россия             Уфа    05 45-54          04 1-5
# 1    SMARTPHONE  Россия           Киров    05 45-54          04 1-5
# ...

# %% [markdown]
# Подключились к базе данных, написали sql-запрос для формирования нужной нам таблицы для построения дашборда, а также для ответа на вопросы в презентации

# %% [markdown]
# ### Ссылка на дашборд:
#
# https://public.tableau.com/app/profile/mikhail2247/viz/project7_16650818121440/Dashboard1?publish=yes
